# %%
# !nvidia-smi
# !pip install ultralytics --quiet
# !pip install opencv-python-headless --quiet

import ultralytics
ultralytics.checks()
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# Setup complete ✅ (12 CPUs, 167.1 GB RAM, 42.9/235.7 GB disk)
# Mounted at /content/drive

# %%
import wandb
from google.colab import userdata
import os
os.environ['WANDB_API_KEY'] = userdata.get('WANDB_API_KEY')
wandb.init(project="Project_yolo11_tests_EV", entity="ertveh-4-lule-university-of-technology")
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: ertveh-4 (ertveh-4-lule-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260516_151142-sqsvd67p</code>
# Syncing run <strong><a href='https://wandb.ai/ertveh-4-lule-university-of-technology/Project_yolo11_tests_EV/runs/sqsvd67p' target="_blank">devout-field-7</a></strong> to <a href='https://wandb.ai/ertveh-4-lule-university-of-technology/Project_yolo11_tests_EV' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
# ...

# %%
import os
import zipfile

ZIP_PATH = '/content/drive/MyDrive/Training_data_10p_normalized.zip'
EXTRACT_DIR = '/content/dataset'

os.makedirs(EXTRACT_DIR, exist_ok=True)

print('Extracting...')
with zipfile.ZipFile(ZIP_PATH, 'r') as zf:
    zf.extractall(EXTRACT_DIR)
print('Done.')

# Verify structure
for root, dirs, files in os.walk(EXTRACT_DIR):
    level = root.replace(EXTRACT_DIR, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    if level < 2:
        for f in files[:3]:
            print(f'{indent}  {f}')
# Out:
# Extracting...
# Done.
# dataset/
#   Training_data_10p_normalized/
#     data_10_normalized.yaml
#     dataset/
#       labels/
#         val/
#         train/
#       images/
#         val/
#         train/

# %%
import yaml

dataset_config = {
    'path': '/content/dataset/Training_data_10p_normalized/dataset',
    'train': 'images/train',
    'val':   'images/val',
    'nc': 1,
    'names': ['car']
}

yaml_path = '/content/dataset.yaml'
with open(yaml_path, 'w') as f:
    yaml.dump(dataset_config, f, default_flow_style=False)

print(open(yaml_path).read())
# Out:
# names:
# - car
# nc: 1
# path: /content/dataset/Training_data_10p_normalized/dataset
# train: images/train
# val: images/val

# %%
import cv2
import matplotlib.pyplot as plt
import random
import glob

def draw_yolo_boxes(img_path, label_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h, w = img.shape[:2]
    if os.path.exists(label_path):
        with open(label_path) as f:
            for line in f:
                cls, cx, cy, bw, bh = map(float, line.strip().split())
                x1 = int((cx - bw/2) * w)
                y1 = int((cy - bh/2) * h)
                x2 = int((cx + bw/2) * w)
                y2 = int((cy + bh/2) * h)
                cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 0), 2)
    return img

image_files = glob.glob('/content/dataset/Training_data_10p_normalized/dataset/images/train/**/*.jpg', recursive=True) + \
              glob.glob('/content/dataset/Training_data_10p_normalized/dataset/images/train/**/*.png', recursive=True)

samples = random.sample(image_files, min(6, len(image_files)))

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
for ax, img_path in zip(axes.flatten(), samples):
    label_path = img_path.replace('images', 'labels').rsplit('.', 1)[0] + '.txt'
    img = draw_yolo_boxes(img_path, label_path)
    ax.imshow(img)
    ax.set_title(os.path.basename(img_path), fontsize=8)
    ax.axis('off')
plt.tight_layout()
plt.show()
print(f'Total training images: {len(image_files)}')
# Out:
# Total training images: 12043

# %%
from ultralytics import YOLO
from ultralytics.utils.callbacks import add_integration_callbacks
model = YOLO('yolov9c.pt')  # pretrained on COCO

add_integration_callbacks(model)

# %%
results = model.train(
    data=yaml_path,
    epochs=100,
    imgsz=1280,
    batch=4,
    device=0,
    workers=2,
    project='/content/runs',
    name='yolov9c_nvd_10p_norm_1280_frozen_aug',
    exist_ok=True,
    pretrained=True,
    freeze=10,
    patience=20,
    save=True,
    plots=True,
    cache='disk',
    amp=True,
    lr0=0.001,
    optimizer='AdamW',
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=15.0,
    translate=0.1,
    scale=0.9,
    mosaic=1.0,
)
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# ...

# %%
best_model = YOLO('/content/runs/yolov9c_nvd_10p_norm_1280_frozen_aug/weights/best.pt')

metrics = best_model.val(data=yaml_path, imgsz=1280, device=0)

print(f"mAP@50:     {metrics.box.map50:.4f}")
print(f"mAP@50-95:  {metrics.box.map:.4f}")
print(f"Precision:  {metrics.box.mp:.4f}")
print(f"Recall:     {metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (NVIDIA A100-SXM4-80GB, 81153MiB)
# YOLOv9c summary (fused): 156 layers, 25,320,019 parameters, 0 gradients, 102.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2458.4±1409.0 MB/s, size: 547.8 KB)
# val: Scanning /content/dataset/Training_data_10p_normalized/dataset/labels/val.cache... 1203 images, 1323 backgrounds, 3 corrupt: 100% ━━━━━━━━━━━━ 2526/2526 882.9Mit/s 0.0s
# val: /content/dataset/Training_data_10p_normalized/dataset/images/val/frame_1944.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0105      1.0112]
# val: /content/dataset/Training_data_10p_normalized/dataset/images/val/frame_2238.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0119]
# val: /content/dataset/Training_data_10p_normalized/dataset/images/val/frame_381.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0116]
# ...

# %%
import shutil, os

DRIVE_OUTPUT = '/content/drive/MyDrive/D7047E Project Datasets/yolov9c_results'
os.makedirs(DRIVE_OUTPUT, exist_ok=True)

shutil.copy('/content/runs/yolov9c_nvd_10p_norm_1280_frozen_aug/weights/best.pt',
            os.path.join(DRIVE_OUTPUT, 'yolov9c_nvd_10p_norm_1280_frozen_aug.pt'))
shutil.copy('/content/runs/yolov9c_nvd_10p_norm_1280_frozen_aug/results.csv',
            os.path.join(DRIVE_OUTPUT, 'yolov9c_nvd_10p_norm_1280_frozen_aug.csv'))
print('Saved.')
# Out:
# Saved.

# %%
from ultralytics import YOLO
import glob
import random

# Load frozen backbone best weights
model = YOLO('/content/runs/yolov9c_nvd_10p_norm_1280_frozen_aug/weights/best.pt')

# Pick a random val image with detections
image_files = glob.glob('/content/dataset/Training_data_10p_normalized/dataset/images/val/**/*.jpg', recursive=True) + \
              glob.glob('/content/dataset/Training_data_10p_normalized/dataset/images/val/**/*.png', recursive=True)

for img_path in random.sample(image_files, 20):
    results = model(img_path, imgsz=1280, conf=0.25, verbose=False)
    if len(results[0].boxes) > 0:
        print(f'Found {len(results[0].boxes)} detection(s) in: {img_path}')
        results[0].save(filename='/content/prediction_frozen.jpg')
        break

from IPython.display import Image
Image('/content/prediction_frozen.jpg')
# Out:
# Found 1 detection(s) in: /content/dataset/Training_data_10p_normalized/dataset/images/val/frame_742.jpg
